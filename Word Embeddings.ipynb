# %% [markdown]
# ## Cleaning text for embeddings
#
# https://github.com/facebookresearch/fastText/issues/333

# %% [markdown]
# ## Visualizing word embeddings

# %%
from IPython.display import IFrame
IFrame('http://projector.tensorflow.org/', width=1000, height=700)

# %% [markdown]
# ## Similarity of text

# %%
import numpy as npimport seaborn as sns
import matplotlib.pyplot as plt

def plot_similarity(labels, features, rotation):
  corr = np.corrcoef(X)#np.inner(features, features)
  sns.set(font_scale=1.2)
  g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
  g.set_xticklabels(labels, rotation=rotation)
  g.set_title("Semantic Textual Similarity")

# %%
plt.figure(figsize=(9, 6))
plot_similarity(test_sentences, X, 90)
